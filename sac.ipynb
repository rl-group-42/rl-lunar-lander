# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import gymnasium as gym
import torch.distributions as dist
import torch.nn.functional as F
from torch import cuda
from torch.backends import mps
from collections import deque
import matplotlib.pyplot as plt
import time

def get_device() -> str:
    """ Get Device Name """
    if cuda.is_available():
        return "cuda"
    elif mps.is_available():
        return "mps"
    else:
        return "cpu"
    
def typeprint(var):
    print(type(var))
    print(var)

class Logger:
    episodes = []
    optimal = []
    optimaleps = []

    actions = []

    def __init__(self):
        self.episodes.append(["t", "length", "reward"])
        self.optimal.append(["t", "avg"])
        self.optimaleps.append(["t", "reward"])

    # def addep(self, t, length, reward):

    def export(self, agent):
        name = "tests\\" + str(int(time.time()))
        with open(name + "_eps.csv", "w") as file:
            for ep in self.episodes:
                file.write(",".join([str(x) for x in ep]) + "\n")
        with open(name + "_optim.csv", "w") as file:
            for data in self.optimal:
                file.write(",".join([str(x) for x in data]) + "\n")
        with open(name + "_optim_eps.csv", "w") as file:
            for data in self.optimaleps:
                file.write(",".join([str(x) for x in data]) + "\n")
        with open(name + "_info.txt", "w") as file:
            file.write(f"entropy Start (alpha): {agent.entropy}\n")
            file.write(f"entropy zero(alpha): {agent.entropy}\n")
            file.write(f"discount (gamma): {agent.discount}\n")
            file.write(f"polyak (1-tau): {agent.polyak}\n")
            file.write(f"learning rate: {agent.l_rate}\n")
            file.write(f"network structure: {agent.hidden}\n")
            file.write(f"minibatch size: {agent.batch_size}\n")



# Stores experiences from the agent
# State - current state
# Action - action performed in that state
# Reward - reward gained from taking the action in the state
# Next State - the state resulting from taking the action from that state
# Done - done signal, true if the next state is terminal, if both legs are touched down
class ReplayBuffer:
    def __init__(self):
        self.buffer = []
        self.maxlen = 50000
    
    def new_memory(self, state, action, reward, next, done):
        self.buffer.append((state, action, reward, next, done))
        if len(self.buffer) > self.maxlen: self.buffer.pop(0)

    # returns a random permutation of a range with the length of the buffer
    def rand_key(self):
        memories = range(len(self.buffer))
        return np.random.permutation(np.array(memories))

    # returns a random selection of the memory
    def rand_sample(self, size):
        sample = []
        for i in self.rand_key()[:size]:
            sample.append(self.buffer[i])
        return sample
    
    def rand_sample_split(self, size):
        state, action, reward, next, done = [], [], [], [], []
        for item in self.rand_sample(size):
            state.append(item[0])
            action.append(item[1])
            reward.append(item[2])
            next.append(item[3])
            done.append(item[4])
        return np.array(state), np.array(action), np.array(reward), np.array(next), np.array(done)

    def rand_batches(self, size):
        key = self.rand_key()
        memories = len(key)
        index = 0
        batches = []
        while index < memories:
            batch = []
            for _ in range(min(size, memories - index)):
                batch.append(self.buffer[key[index]])
            batches.append(batch)


class ActorNet(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dims=[500, 500], l_rate=0.0003):
        super(ActorNet, self).__init__()

        # Set up layers
        layers = []
        prev_dim = input_dim
        for dim in hidden_dims:
            layers.append(nn.Linear(prev_dim, dim))
            # layers.append(nn.LeakyReLU())
            layers.append(nn.ReLU())
            prev_dim = dim
        self.network = nn.Sequential(*layers)
        # self.mean_layer = nn.Sequential(nn.Linear(prev_dim, output_dim), nn.Tanh())
        self.mean_layer = nn.Linear(prev_dim, output_dim)
        # self.logstd_layer = nn.Sequential(nn.Linear(prev_dim, output_dim), nn.Softplus())
        self.logstd_layer = nn.Linear(prev_dim, output_dim)

        # self.optimizer = optim.Adam(self.parameters(), lr = l_rate)
        self.optimizer = optim.Adam(self.parameters(), lr = l_rate)

    # gets a mean and standard deviation value for each action
    def forward(self, state):
        output = self.network(state)
        mean = self.mean_layer(output)

        # maybe experiment with clamp values
        logstd = torch.clamp(self.logstd_layer(output), -3, 2)

        return mean, logstd
    
    def sample_normal(self, state):
        mean, logstd = self.forward(state)
        std = logstd.exp()
        dist = torch.distributions.Normal(mean, std)
        sample = dist.rsample() # used to just be sample, source of all my problems?
        action = torch.tanh(sample)

        log_prob = dist.log_prob(sample)
        log_pi = torch.sum(log_prob, dim=1, keepdim=True)
        return action, log_pi
    
class CriticNet(nn.Module):
    def __init__(self, input_dim, hidden_dims=[500, 500], l_rate=0.0003):
        super(CriticNet, self).__init__()

        # Set up layers
        layers = []
        prev_dim = input_dim
        for dim in hidden_dims:
            layers.append(nn.Linear(prev_dim, dim))
            # layers.append(nn.LeakyReLU())
            layers.append(nn.ReLU())
            prev_dim = dim
        layers.append(nn.Linear(prev_dim, 1))
        self.network = nn.Sequential(*layers)

        self.optimizer = optim.Adam(self.parameters(), lr = l_rate)

    def forward(self, action, state):
        input = torch.cat((action, state), dim=1)
        output = self.network(input)
        return output


class SACAgent:
    def __init__(self, env: gym.Env):

        self.device = torch.device(get_device())
        self.env = env
        input_dim = env.observation_space.shape[0]
        output_dim = env.action_space.shape[0]

        self.memory = ReplayBuffer()
        # self.valloss = []
        self.crit1loss = []
        self.crit2loss = []
        self.actorloss = []


        # new stuff vv
        self.entropystart = 0.3 # alpha 0.2 start
        self.entropy = self.entropystart
        self.entropyzero = 0.9
        self.discount = 0.99 # gamma
        self.polyak = 0.99 # 1 - tau
        l_rate = 0.0003
        hidden = [512, 512]

        # for logging
        self.l_rate = l_rate
        self.hidden = hidden

        self.batch_size = 128

        self.actor = ActorNet(input_dim, output_dim, l_rate=l_rate, hidden_dims=hidden).to(self.device)
        self.critic1 = CriticNet(input_dim + output_dim, l_rate=l_rate, hidden_dims=hidden).to(self.device)
        self.critic2 = CriticNet(input_dim + output_dim, l_rate=l_rate, hidden_dims=hidden).to(self.device)
        self.critic1tar = CriticNet(input_dim + output_dim, l_rate=l_rate, hidden_dims=hidden).to(self.device)
        self.critic2tar = CriticNet(input_dim + output_dim, l_rate=l_rate, hidden_dims=hidden).to(self.device)

        # initializing target networks to equal the live ones
        for target, live in zip(self.critic1.parameters(), self.critic1tar.parameters()):
            target.data.copy_(live.data)
        for target, live in zip(self.critic2.parameters(), self.critic2tar.parameters()):
            target.data.copy_(live.data)

        # maybe some stuff here about optimizing alpha??

    def get_tensor (self, array):
        return torch.from_numpy(array).float().to(self.device)
    
    def get_numpy(self, tensor):
        return tensor.cpu().detach().numpy()

    def get_action(self, state):
        state_tensor = self.get_tensor(state)
        action, std = self.actor.sample_normal(state_tensor)
        return action, std
    
    def get_single_action(self, state):
        state_tensor = self.get_tensor(state).unsqueeze(0)
        action, std = self.actor.sample_normal(state_tensor)
        return self.get_numpy(action.squeeze()), std
    
    def printstatus(self, t, rewards, ends, lens):
        index = -min(len(ends), 10)
        bindex = -min(len(ends), 100)
        output = "Ep: " + str(len(ends))
        output += ", Reward: " + str(int(rewards[-1]))
        output += ", Ep start: " + str(t)
        output += ", avg reward: " + str(int(sum(rewards[index:])/-index))
        output += ", avg len: " + str(int(sum(lens[index:])/-index)) + "  "
        # output += ", truncated: " + str(sum(ends[bindex:])) + "%  "
        print("\r" + output, end="")

    def run_ep(self, t):

        terminal = False
        state = self.env.reset()[0]
        epreward = 0
        while not terminal:
            action, _ = self.actor.forward(self.get_tensor(state))
            state, reward, isterminal, truncated, _ = self.env.step(self.get_numpy(action))
            terminal = isterminal or truncated
            epreward += reward
        logger.optimaleps.append([t, epreward])
        return epreward
    
    def runs_avg(self, runs, t):
        rewards = []
        for _ in range(runs):
            rewards.append(self.run_ep(t))
        avg = sum(rewards)/runs
        logger.optimal.append([t, avg])
        return avg

    def train(self, episodes, maxsteps=200000, exploration=4000):
        reward_hist = []
        ends = []
        lens = []
        ep_start = 0
        total_reward = 0
        terminal = False
        current_state = self.env.reset()[0]
        for t in range(maxsteps):
            if len(ends) >= episodes: 
                break
            if t % 4000 == 0:
                print("real score: " + str(int(self.runs_avg(100, t))))
            if terminal:
                # current_state = self.env.reset(seed=1)[0]
                current_state = self.env.reset()[0]

                reward_hist.append(total_reward)
                ends.append(truncated)
                lens.append(t-ep_start)
                self.printstatus(t, reward_hist, ends, lens)

                # logging
                logger.episodes.append([t, t-ep_start, total_reward])
                

                total_reward = 0
                ep_start = t

            
            if t < exploration:
                action = self.env.action_space.sample()
            else:
                action, _ = self.get_single_action(current_state)
            logger.actions.append(action)
            next_state, reward, isterminal, truncated, _ = self.env.step(action)
            total_reward += reward
            terminal = 1 if isterminal or truncated else 0
            self.memory.new_memory(current_state, action, reward, next_state, terminal)
            current_state = next_state
            if self.entropyzero > 0: self.entropy = max(0, self.entropystart * (1 - (len(lens)/episodes) / self.entropyzero))
            if t == exploration: 
                for _ in range(100): self.train_networks()
            if t > exploration:
                self.train_networks()
                self.train_networks()
        print()
        return reward_hist

    # memory: 0 state, 1 action, 2 reward, 3 next, 4 done
    def train_networks(self):
        states, actions, rewards, nexts, dones = self.memory.rand_sample_split(self.batch_size)
        states = self.get_tensor(states)
        actions = self.get_tensor(actions)
        rewards = self.get_tensor(rewards).unsqueeze(1)
        nexts = self.get_tensor(nexts)
        dones = self.get_tensor(dones).unsqueeze(1)
        # print(states[0])
        # print(actions[0])
        # print(rewards[0])
        # print(nexts[0])
        # print(dones[0])

        # getting sample actions using the next states
        next_act, next_log_prob = self.actor.sample_normal(nexts)

        # getting the critic targets
        next_q1 = self.critic1tar.forward(next_act, nexts)
        next_q2 = self.critic2tar.forward(next_act, nexts)
        next_q = torch.min(next_q1, next_q2) - self.entropy * next_log_prob
        # not sure if i need to detach, not done in other places
        tar_q = rewards + (1-dones) * self.discount * next_q.detach()

        curr_q1 = self.critic1.forward(actions, states)
        crit_loss1 = torch.nn.functional.mse_loss(curr_q1, tar_q)
        self.crit1loss.append(self.get_numpy(crit_loss1))
        self.critic1.optimizer.zero_grad()
        crit_loss1.backward()
        self.critic1.optimizer.step()
        
        curr_q2 = self.critic2.forward(actions, states)
        crit_loss2 = torch.nn.functional.mse_loss(curr_q2, tar_q)
        self.crit2loss.append(self.get_numpy(crit_loss2))
        self.critic2.optimizer.zero_grad()
        crit_loss2.backward()
        self.critic2.optimizer.step()

        sample_act, sample_log_prob = self.actor.sample_normal(states)
        act_q1 = self.critic1.forward(sample_act, states)
        act_q2 = self.critic2.forward(sample_act, states)
        act_q = torch.min(act_q1, act_q2)
        act_loss = (self.entropy * sample_log_prob) - act_q
        act_loss = torch.mean(act_loss)
        self.actorloss.append(self.get_numpy(act_loss))
        self.actor.optimizer.zero_grad()
        act_loss.backward()
        self.actor.optimizer.step()

        self.polyak_update()

        # maybe some stuff about optimizing alpha


    def polyak_update(self):
        for target, real in zip(self.critic1tar.parameters(), self.critic1.parameters()):
            target.data.copy_((self.polyak * target.data) + ((1-self.polyak) * real.data))
        for target, real in zip(self.critic2tar.parameters(), self.critic2.parameters()):
            target.data.copy_((self.polyak * target.data) + ((1-self.polyak) * real.data))

logger = Logger()

# %%
#  # env: gym.Env, batch_size, discount, start_training, polyak, entropy
# def main():
env = gym.make("LunarLander-v2", 
        continuous=True)
print("using " + get_device())
# torch.autograd.set_detect_anomaly(True)
# print(env.action_space)
# print(env.action_space.shape)
# print(env.observation_space)
# print(env.observation_space.shape[0])
# print(env.reset()[0])
# print(type(env.reset()[0]))
agent = SACAgent(env)
rewards = agent.train(1200, maxsteps=20000000, exploration=4000)
logger.export(agent)
# Out:
# using cuda
# real score: -261
# Ep: 38, Reward: -318, Ep start: 3944, avg reward: -265, avg len: 110  real score: -270
# Ep: 45, Reward: -58, Ep start: 7027, avg reward: -272, avg len: 337   real score: -46
# Ep: 49, Reward: -79, Ep start: 11001, avg reward: -183, avg len: 700  real score: -152
# Ep: 53, Reward: -74, Ep start: 15001, avg reward: -73, avg len: 954  real score: -97
# Ep: 58, Reward: -93, Ep start: 19694, avg reward: -85, avg len: 969   real score: -181
# Ep: 62, Reward: -73, Ep start: 23001, avg reward: -89, avg len: 900   real score: -177
# Ep: 66, Reward: -69, Ep start: 27001, avg reward: -101, avg len: 900   real score: -157
# Ep: 70, Reward: -132, Ep start: 31001, avg reward: -97, avg len: 1000  real score: -130
# Ep: 74, Reward: -65, Ep start: 35001, avg reward: -96, avg len: 1000   real score: -145
# Ep: 78, Reward: -109, Ep start: 39001, avg reward: -100, avg len: 1000  real score: -240
# Ep: 83, Reward: -92, Ep start: 43758, avg reward: -122, avg len: 975    real score: -157
# Ep: 87, Reward: -80, Ep start: 47001, avg reward: -120, avg len: 900   real score: -85
# Ep: 91, Reward: -54, Ep start: 51001, avg reward: -80, avg len: 924   real score: -60
# Ep: 95, Reward: -112, Ep start: 55001, avg reward: -94, avg len: 1000  real score: -128
# Ep: 99, Reward: -121, Ep start: 59001, avg reward: -103, avg len: 1000  real score: -23
# Ep: 103, Reward: -33, Ep start: 63027, avg reward: -83, avg len: 1002   real score: -100
# Ep: 107, Reward: -88, Ep start: 67001, avg reward: -69, avg len: 1000  real score: -80
# Ep: 111, Reward: -116, Ep start: 71001, avg reward: -78, avg len: 997  real score: -38
# Ep: 115, Reward: -97, Ep start: 75001, avg reward: -87, avg len: 1000   real score: -217
# Ep: 119, Reward: -83, Ep start: 79001, avg reward: -121, avg len: 1000   real score: -103
# Ep: 126, Reward: -140, Ep start: 83975, avg reward: -130, avg len: 797   real score: -54
# Ep: 133, Reward: -180, Ep start: 87363, avg reward: -99, avg len: 474   real score: -171
# Ep: 138, Reward: -112, Ep start: 91403, avg reward: -87, avg len: 727   real score: -13
# Ep: 142, Reward: 104, Ep start: 95001, avg reward: -39, avg len: 863   real score: -84
# Ep: 149, Reward: 103, Ep start: 99759, avg reward: 13, avg len: 775   real score: -42
# Ep: 156, Reward: -192, Ep start: 103657, avg reward: -44, avg len: 547  real score: -81
# Ep: 162, Reward: -165, Ep start: 107543, avg reward: -115, avg len: 680  real score: -40
# Ep: 167, Reward: -56, Ep start: 111111, avg reward: -126, avg len: 707   real score: -173
# Ep: 171, Reward: -109, Ep start: 115001, avg reward: -144, avg len: 816  real score: -204
# Ep: 175, Reward: -165, Ep start: 119001, avg reward: -164, avg len: 989  real score: -145
# Ep: 179, Reward: -165, Ep start: 123001, avg reward: -168, avg len: 1000  real score: -125
# Ep: 183, Reward: -152, Ep start: 127001, avg reward: -153, avg len: 1000  real score: -56
# Ep: 187, Reward: -210, Ep start: 131001, avg reward: -136, avg len: 1000  real score: -208
# Ep: 192, Reward: 87, Ep start: 135126, avg reward: -107, avg len: 912     real score: 0
# Ep: 199, Reward: -41, Ep start: 139973, avg reward: -56, avg len: 697    real score: -27
# Ep: 204, Reward: -94, Ep start: 143843, avg reward: -108, avg len: 684   real score: -128
# Ep: 209, Reward: -141, Ep start: 147182, avg reward: -124, avg len: 720  real score: -159
# Ep: 213, Reward: -38, Ep start: 151001, avg reward: -104, avg len: 815   real score: -157
# Ep: 217, Reward: -127, Ep start: 155001, avg reward: -122, avg len: 900  real score: -126
# Ep: 221, Reward: -82, Ep start: 159001, avg reward: -114, avg len: 1000   real score: -22
# Ep: 226, Reward: -129, Ep start: 163439, avg reward: -78, avg len: 943    real score: -75
# Ep: 230, Reward: -85, Ep start: 167001, avg reward: -60, avg len: 900   real score: -86
# Ep: 235, Reward: -168, Ep start: 171938, avg reward: -119, avg len: 949  real score: -128
# Ep: 240, Reward: -218, Ep start: 175934, avg reward: -122, avg len: 893  real score: -141
# Ep: 245, Reward: -183, Ep start: 179003, avg reward: -110, avg len: 706  real score: -130
# Ep: 250, Reward: -123, Ep start: 183909, avg reward: -139, avg len: 797  real score: -134
# Ep: 255, Reward: -259, Ep start: 187240, avg reward: -158, avg len: 823  real score: -68
# Ep: 260, Reward: -156, Ep start: 191114, avg reward: -142, avg len: 720  real score: -97
# Ep: 265, Reward: -77, Ep start: 195048, avg reward: -104, avg len: 780   real score: -135
# Ep: 269, Reward: -85, Ep start: 199001, avg reward: -90, avg len: 888   real score: -130
# Ep: 274, Reward: -134, Ep start: 203288, avg reward: -92, avg len: 924  real score: -66
# Ep: 281, Reward: -166, Ep start: 207706, avg reward: -140, avg len: 670  real score: -96
# Ep: 286, Reward: -124, Ep start: 211313, avg reward: -139, avg len: 631  real score: -126
# Ep: 295, Reward: -94, Ep start: 215749, avg reward: -124, avg len: 475   real score: -126
# Ep: 300, Reward: -30, Ep start: 219361, avg reward: -109, avg len: 513   real score: -161
# Ep: 305, Reward: -290, Ep start: 223827, avg reward: -126, avg len: 807  real score: -97
# Ep: 311, Reward: 94, Ep start: 227663, avg reward: -107, avg len: 766    real score: -143
# Ep: 317, Reward: -231, Ep start: 231533, avg reward: -131, avg len: 653  real score: -133
# Ep: 323, Reward: -152, Ep start: 235520, avg reward: -144, avg len: 691  real score: -97
# Ep: 328, Reward: -73, Ep start: 239536, avg reward: -116, avg len: 753   real score: -125
# Ep: 333, Reward: -94, Ep start: 243281, avg reward: -97, avg len: 776    real score: -71
# Ep: 337, Reward: -102, Ep start: 247001, avg reward: -79, avg len: 846  real score: -89
# Ep: 342, Reward: -90, Ep start: 251509, avg reward: -88, avg len: 850   real score: -138
# Ep: 352, Reward: -123, Ep start: 255444, avg reward: -135, avg len: 393  real score: -71
# Ep: 357, Reward: -87, Ep start: 259300, avg reward: -66, avg len: 501   real score: -119
# Ep: 361, Reward: -89, Ep start: 263001, avg reward: -58, avg len: 775   real score: -83
# Ep: 365, Reward: -51, Ep start: 267001, avg reward: -87, avg len: 970  real score: -95
# Ep: 369, Reward: -58, Ep start: 271001, avg reward: -84, avg len: 1000  real score: -80
# Ep: 374, Reward: -90, Ep start: 275218, avg reward: -66, avg len: 921   real score: -134
# Ep: 379, Reward: -61, Ep start: 279275, avg reward: -86, avg len: 827   real score: -57
# Ep: 383, Reward: -88, Ep start: 283001, avg reward: -82, avg len: 800   real score: -43
# Ep: 390, Reward: -182, Ep start: 287488, avg reward: -39, avg len: 748  real score: -82
# Ep: 397, Reward: -38, Ep start: 291875, avg reward: -101, avg len: 637  real score: -40
# Ep: 402, Reward: -56, Ep start: 295554, avg reward: -63, avg len: 698   real score: -11
# Ep: 409, Reward: 122, Ep start: 299439, avg reward: -4, avg len: 665    real score: -58
# Ep: 413, Reward: -67, Ep start: 303001, avg reward: 3, avg len: 700    real score: -31
# Ep: 417, Reward: -31, Ep start: 307001, avg reward: -6, avg len: 885  real score: -23
# Ep: 423, Reward: -59, Ep start: 311216, avg reward: -27, avg len: 821   real score: -53
# Ep: 430, Reward: -86, Ep start: 315864, avg reward: -51, avg len: 678   real score: -81
# Ep: 435, Reward: 5, Ep start: 319994, avg reward: -22, avg len: 699    real score: -95
# Ep: 440, Reward: 55, Ep start: 323880, avg reward: 25, avg len: 801    real score: -58
# Ep: 445, Reward: -8, Ep start: 327885, avg reward: 12, avg len: 789   real score: 40
# Ep: 451, Reward: -195, Ep start: 331867, avg reward: 12, avg len: 786  real score: 30
# Ep: 458, Reward: 174, Ep start: 335877, avg reward: -19, avg len: 602   real score: 67
# Ep: 463, Reward: 6, Ep start: 339511, avg reward: 15, avg len: 629     real score: 112
# Ep: 468, Reward: -43, Ep start: 343754, avg reward: 68, avg len: 787  real score: 3
# Ep: 473, Reward: 39, Ep start: 347198, avg reward: 98, avg len: 768   real score: 81
# Ep: 479, Reward: -24, Ep start: 351877, avg reward: 93, avg len: 787   real score: 84
# Ep: 485, Reward: 169, Ep start: 355294, avg reward: 103, avg len: 629  real score: 7
# Ep: 490, Reward: 171, Ep start: 359392, avg reward: 116, avg len: 735  real score: 67
# Ep: 495, Reward: 62, Ep start: 363081, avg reward: 102, avg len: 778   real score: 115
# Ep: 500, Reward: 73, Ep start: 367922, avg reward: 116, avg len: 853   real score: 56
# Ep: 508, Reward: -52, Ep start: 371850, avg reward: 41, avg len: 592   real score: 69
# Ep: 516, Reward: 45, Ep start: 375933, avg reward: 3, avg len: 521    real score: -9
# Ep: 521, Reward: 174, Ep start: 379824, avg reward: -7, avg len: 652  real score: -34
# Ep: 527, Reward: 4, Ep start: 383911, avg reward: 2, avg len: 791     real score: -48
# Ep: 531, Reward: -49, Ep start: 387001, avg reward: -21, avg len: 717  real score: -37
# Ep: 538, Reward: -48, Ep start: 391806, avg reward: -20, avg len: 780  real score: 5
# Ep: 544, Reward: 129, Ep start: 395870, avg reward: 33, avg len: 584   real score: 94
# Ep: 549, Reward: 111, Ep start: 399007, avg reward: 86, avg len: 700  real score: 61
# Ep: 553, Reward: -13, Ep start: 403001, avg reward: 98, avg len: 769   real score: -24
# Ep: 559, Reward: 141, Ep start: 407951, avg reward: 55, avg len: 894   real score: 62
# Ep: 564, Reward: -5, Ep start: 411891, avg reward: 53, avg len: 789   real score: 79
# Ep: 570, Reward: 147, Ep start: 415718, avg reward: 62, avg len: 771  real score: 8
# Ep: 574, Reward: 4, Ep start: 419001, avg reward: 22, avg len: 711    real score: 80
# Ep: 579, Reward: -51, Ep start: 423893, avg reward: 37, avg len: 894  real score: -22
# Ep: 584, Reward: 181, Ep start: 427555, avg reward: 54, avg len: 855  real score: 115
# Ep: 590, Reward: 34, Ep start: 431878, avg reward: 107, avg len: 787   real score: 44
# Ep: 595, Reward: 84, Ep start: 435773, avg reward: 117, avg len: 777   real score: 113
# Ep: 600, Reward: 50, Ep start: 439392, avg reward: 112, avg len: 751   real score: 137
# Ep: 604, Reward: 84, Ep start: 443001, avg reward: 100, avg len: 822   real score: 124
# Ep: 611, Reward: 63, Ep start: 447966, avg reward: 109, avg len: 796   real score: 72
# Ep: 617, Reward: 22, Ep start: 451825, avg reward: 73, avg len: 677   real score: 101
# Ep: 622, Reward: 52, Ep start: 455720, avg reward: 54, avg len: 771   real score: 112
# Ep: 628, Reward: 187, Ep start: 459679, avg reward: 73, avg len: 718  real score: 118
# Ep: 633, Reward: -56, Ep start: 463259, avg reward: 87, avg len: 725   real score: 23
# Ep: 639, Reward: 130, Ep start: 467743, avg reward: 96, avg len: 774   real score: 122
# Ep: 644, Reward: -56, Ep start: 471274, avg reward: 88, avg len: 727   real score: 124
# Ep: 650, Reward: 213, Ep start: 475636, avg reward: 116, avg len: 763  real score: 137
# Ep: 656, Reward: -76, Ep start: 479169, avg reward: 128, avg len: 657  real score: 67
# Ep: 660, Reward: 43, Ep start: 483028, avg reward: 114, avg len: 739   real score: 26
# Ep: 664, Reward: 112, Ep start: 487001, avg reward: 63, avg len: 983  real score: 77
# Ep: 668, Reward: -2, Ep start: 491026, avg reward: 66, avg len: 999   real score: 72
# Ep: 674, Reward: 163, Ep start: 495823, avg reward: 88, avg len: 882  real score: 118
# Ep: 679, Reward: 144, Ep start: 499409, avg reward: 125, avg len: 740  real score: 92
# Ep: 684, Reward: 152, Ep start: 503092, avg reward: 145, avg len: 726  real score: 95
# Ep: 688, Reward: -50, Ep start: 507025, avg reward: 110, avg len: 861  real score: 42
# Ep: 694, Reward: 209, Ep start: 511708, avg reward: 97, avg len: 861  real score: 74
# Ep: 700, Reward: 155, Ep start: 515462, avg reward: 160, avg len: 646  real score: 113
# Ep: 705, Reward: 170, Ep start: 519644, avg reward: 119, avg len: 764  real score: 113
# Ep: 710, Reward: 83, Ep start: 523294, avg reward: 109, avg len: 783   real score: 53
# Ep: 716, Reward: -36, Ep start: 527711, avg reward: 106, avg len: 771  real score: 114
# Ep: 721, Reward: 189, Ep start: 531830, avg reward: 118, avg len: 782  real score: 113
# Ep: 727, Reward: 171, Ep start: 535817, avg reward: 150, avg len: 781  real score: 112
# Ep: 733, Reward: 103, Ep start: 539414, avg reward: 174, avg len: 641  real score: 146
# Ep: 738, Reward: 159, Ep start: 543992, avg reward: 154, avg len: 796  real score: 129
# Ep: 744, Reward: 242, Ep start: 547658, avg reward: 124, avg len: 765  real score: 134
# Ep: 749, Reward: 214, Ep start: 551346, avg reward: 140, avg len: 734  real score: 132
# Ep: 756, Reward: 227, Ep start: 555837, avg reward: 174, avg len: 678  real score: 152
# Ep: 763, Reward: 204, Ep start: 559559, avg reward: 183, avg len: 515  real score: 153
# Ep: 771, Reward: 70, Ep start: 563949, avg reward: 150, avg len: 574   real score: 161
# Ep: 778, Reward: 101, Ep start: 567576, avg reward: 134, avg len: 593  real score: 142
# Ep: 784, Reward: 208, Ep start: 571570, avg reward: 169, avg len: 675  real score: 136
# Ep: 789, Reward: 131, Ep start: 575318, avg reward: 160, avg len: 731  real score: 163
# Ep: 794, Reward: 177, Ep start: 579305, avg reward: 168, avg len: 773  real score: 131
# Ep: 798, Reward: 72, Ep start: 583001, avg reward: 128, avg len: 868   real score: 32
# Ep: 803, Reward: 242, Ep start: 587220, avg reward: 64, avg len: 840   real score: 103
# Ep: 808, Reward: 121, Ep start: 591339, avg reward: 76, avg len: 833  real score: 136
# Ep: 814, Reward: 101, Ep start: 595779, avg reward: 133, avg len: 777  real score: 152
# Ep: 821, Reward: 114, Ep start: 599486, avg reward: 184, avg len: 610  real score: 150
# Ep: 827, Reward: 248, Ep start: 603712, avg reward: 160, avg len: 636  real score: 152
# Ep: 833, Reward: 220, Ep start: 607599, avg reward: 170, avg len: 659  real score: 146
# Ep: 837, Reward: 141, Ep start: 611001, avg reward: 151, avg len: 728  real score: 122
# Ep: 843, Reward: 121, Ep start: 615730, avg reward: 141, avg len: 813  real score: 139
# Ep: 849, Reward: 144, Ep start: 619813, avg reward: 164, avg len: 737  real score: 166
# Ep: 853, Reward: 138, Ep start: 623001, avg reward: 145, avg len: 727  real score: 187
# Ep: 857, Reward: 129, Ep start: 627001, avg reward: 134, avg len: 847  real score: 157
# Ep: 864, Reward: 89, Ep start: 631935, avg reward: 133, avg len: 793   real score: 146
# Ep: 869, Reward: 133, Ep start: 635273, avg reward: 139, avg len: 707  real score: 168
# Ep: 876, Reward: 111, Ep start: 639911, avg reward: 159, avg len: 763  real score: 154
# Ep: 881, Reward: 148, Ep start: 643847, avg reward: 140, avg len: 695  real score: 169
# Ep: 887, Reward: 208, Ep start: 647419, avg reward: 157, avg len: 741  real score: 163
# Ep: 892, Reward: 194, Ep start: 651363, avg reward: 160, avg len: 736  real score: 171
# Ep: 898, Reward: 9, Ep start: 655887, avg reward: 142, avg len: 788    real score: 168
# Ep: 905, Reward: 250, Ep start: 659937, avg reward: 151, avg len: 628  real score: 184
# Ep: 912, Reward: 227, Ep start: 663042, avg reward: 203, avg len: 450  real score: 135
# Ep: 917, Reward: 110, Ep start: 667519, avg reward: 168, avg len: 706  real score: 149
# Ep: 923, Reward: 110, Ep start: 671697, avg reward: 150, avg len: 769  real score: 157
# Ep: 928, Reward: 108, Ep start: 675205, avg reward: 158, avg len: 718  real score: 172
# Ep: 934, Reward: 117, Ep start: 679399, avg reward: 164, avg len: 739  real score: 206
# Ep: 940, Reward: 70, Ep start: 683740, avg reward: 163, avg len: 695   real score: 193
# Ep: 946, Reward: 248, Ep start: 687812, avg reward: 180, avg len: 681  real score: 157
# Ep: 952, Reward: 263, Ep start: 691076, avg reward: 186, avg len: 604  real score: 142
# Ep: 958, Reward: 245, Ep start: 695474, avg reward: 188, avg len: 647  real score: 167
# Ep: 963, Reward: 248, Ep start: 699556, avg reward: 170, avg len: 755  real score: 214
# Ep: 968, Reward: 201, Ep start: 703478, avg reward: 174, avg len: 800  real score: 163
# Ep: 975, Reward: 219, Ep start: 707233, avg reward: 177, avg len: 620  real score: 146
# Ep: 981, Reward: 124, Ep start: 711776, avg reward: 165, avg len: 604  real score: 159
# Ep: 988, Reward: 170, Ep start: 715907, avg reward: 179, avg len: 659  real score: 155
# Ep: 992, Reward: 118, Ep start: 719001, avg reward: 161, avg len: 700  real score: 152
# Ep: 998, Reward: 239, Ep start: 723325, avg reward: 156, avg len: 741  real score: 207
# Ep: 1006, Reward: 248, Ep start: 727920, avg reward: 203, avg len: 509  real score: 198
# Ep: 1015, Reward: 261, Ep start: 731658, avg reward: 188, avg len: 401  real score: 164
# Ep: 1022, Reward: 222, Ep start: 735666, avg reward: 227, avg len: 480  real score: 134
# Ep: 1027, Reward: 181, Ep start: 739006, avg reward: 196, avg len: 617  real score: 143
# Ep: 1035, Reward: 216, Ep start: 743893, avg reward: 176, avg len: 664  real score: 213
# Ep: 1041, Reward: 201, Ep start: 747754, avg reward: 173, avg len: 613  real score: 172
# Ep: 1051, Reward: 240, Ep start: 751665, avg reward: 217, avg len: 391  real score: 162
# Ep: 1057, Reward: 237, Ep start: 755858, avg reward: 173, avg len: 618  real score: 206
# Ep: 1063, Reward: 111, Ep start: 759142, avg reward: 169, avg len: 697  real score: 208
# Ep: 1071, Reward: 217, Ep start: 763256, avg reward: 205, avg len: 564  real score: 214
# Ep: 1077, Reward: 232, Ep start: 767876, avg reward: 199, avg len: 581  real score: 209
# Ep: 1084, Reward: 264, Ep start: 771244, avg reward: 199, avg len: 547  real score: 167
# Ep: 1091, Reward: 238, Ep start: 775860, avg reward: 205, avg len: 598  real score: 221
# Ep: 1095, Reward: 115, Ep start: 779026, avg reward: 170, avg len: 699  real score: 193
# Ep: 1101, Reward: 218, Ep start: 783786, avg reward: 172, avg len: 792  real score: 200
# Ep: 1107, Reward: 113, Ep start: 787234, avg reward: 213, avg len: 623  real score: 213
# Ep: 1115, Reward: 226, Ep start: 791905, avg reward: 210, avg len: 667  real score: 190
# Ep: 1123, Reward: 96, Ep start: 795962, avg reward: 215, avg len: 508   real score: 205
# Ep: 1131, Reward: 108, Ep start: 799717, avg reward: 196, avg len: 508  real score: 205
# Ep: 1137, Reward: 153, Ep start: 803663, avg reward: 210, avg len: 614  real score: 228
# Ep: 1143, Reward: 272, Ep start: 807391, avg reward: 206, avg len: 700  real score: 223
# Ep: 1148, Reward: 138, Ep start: 811268, avg reward: 197, avg len: 724  real score: 151
# Ep: 1154, Reward: 117, Ep start: 815931, avg reward: 177, avg len: 790  real score: 143
# Ep: 1160, Reward: 27, Ep start: 819335, avg reward: 134, avg len: 634   real score: 115
# Ep: 1168, Reward: 88, Ep start: 823903, avg reward: 135, avg len: 490   real score: 149
# Ep: 1175, Reward: 152, Ep start: 827406, avg reward: 200, avg len: 553  real score: 219
# Ep: 1180, Reward: 138, Ep start: 831090, avg reward: 211, avg len: 629  real score: 202
# Ep: 1185, Reward: 155, Ep start: 835552, avg reward: 184, avg len: 814  real score: 149
# Ep: 1192, Reward: 275, Ep start: 839645, avg reward: 182, avg len: 662  real score: 238
# Ep: 1198, Reward: 102, Ep start: 843890, avg reward: 203, avg len: 639  real score: 232
# Ep: 1200, Reward: 132, Ep start: 845032, avg reward: 186, avg len: 614

# %%
def visualrun(agent):
    env = gym.make('LunarLander-v2')

    terminal = False
    state = env.reset()[0]
    epreward = 0
    while not terminal:
        action, _ = agent.actor.forward(agent.get_tensor(state))
        state, reward, isterminal, truncated, _ = env.step(agent.get_numpy(action))
        terminal = isterminal or truncated
        epreward += reward
    # logger.optimaleps.append([t, epreward])
    input()
    env.close()
    return epreward

# %%
print(visualrun(agent))
# print(agent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(visualrun(agent))
#       2 # print(agent)
#
# NameError: name 'agent' is not defined

# %%
# print("final avg score: " + str(agent.runs_avg(100)))
# exit()
i = 0
batch = 100
# print(len(logger.actions))
# print(logger.actions[0])
# logger.actions = np.array(logger.actions)
act_mean = []
act_std = []
while i + batch < len(logger.actions):
    arr = np.array(logger.actions[i:i+batch])
    # arr.mean()
    # print(arr.mean())
    # print(arr.std())
    # print(arr.mean(axis=0))
    # print(arr.std(axis=0))
    act_mean.append(arr.mean(axis=0))
    act_std.append(arr.std(axis=0))
    i += batch

print()
print(len(rewards))
# plt.subplot(1, 2, 1)
# plt.title("Episode Rewards")
# plt.plot(rewards)
# plt.title("Gradient Norms")
# plt.plot(valgrads, label="Value")
# plt.plot(crit1grads, label="Critic 1")
# plt.plot(crit2grads, label="Critic 2")
# plt.plot(actgrads, label="Actor")
plt.subplot(1, 2, 1)
plt.title("Actions")
m = np.array([x[0] for x in act_mean])
d = np.array([x[0] for x in act_std])
plt.plot(m, label="Action 0 Mean")
plt.fill_between(range(len(m)), m-d, m+d, label="Action 0 Std Dev", alpha=0.5)
m = np.array([x[1] for x in act_mean])
d = np.array([x[1] for x in act_std])
plt.plot(m, label="Action 1 Mean")
plt.fill_between(range(len(m)), m-d, m+d, label="Action 1 Std Dev", alpha=0.5)
# plt.plot([x[0] for x in act_std], label="Action 0 Std Dev", color="blue")
# plt.plot([x[1] for x in act_mean], label="Action 1 Mean", color="orange")
# plt.plot([x[1] for x in act_std], label="Action 1 Std Dev", color="red")
# plt.plot(, label="")
# plt.plot(, label="")
# plt.plot(, label="")
# plt.plot(, label="")
plt.subplot(1, 2, 2)
plt.title("Loss")
# plt.plot(agent.valloss, label="Value")
plt.plot(agent.crit1loss, label="Critic 1")
plt.plot(agent.crit2loss, label="Critic 2")
plt.plot(agent.actorloss, label="Actor")
plt.legend()
plt.show()
    # print(len(agent.memory.buffer))
    # print(agent.get_action(env.reset()[0]))
# Out:
# 1200
